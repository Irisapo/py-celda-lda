# %%
import pandas as pd
import numpy as np

import pymc3 as pm 
from pymc3 import math as pmmath 
from pymc3 import Dirichlet
from pymc3.distributions.transforms import t_stick_breaking

import theano 
from theano import shared
import theano.tensor as tt
from theano.sandbox.rng_mrg import MRG_RandomStreams

from collections import OrderedDict

theano.config.compute_test_value = 'ignore'

# %%
sim_counts = np.load("./celda_simulated/simCG_counts_K5L6.npy")

counts_share = theano.shared(sim_counts)

# %%
n_topics = 5 
n_subppl = 6   # choose it same as n_topics ? 
n_genes = sim_counts.shape[1]
print("the shape of the doc is {}".format(sim_counts.shape))   # cell x gene : 444 x 999
print(type(sim_counts))
# Out:
# the shape of the doc is (444, 999)
# <class 'numpy.ndarray'>

# %%
def logp_lda_doc(theta, phi, psi):
    """return the loglikelihood 
    Z: number of topics in the model 
    M: number of cells 
    K: number of cellular subpopulation 
    N: number of genes 
    parameters
    ----------
    theta:  tensor (M x Z)
      Topic distribution for document 
    phi:  tensor (Z x K) 
      Cellular subpopulation distribution within topic
    psi: tensor (K x N)
      Gene distributions. 
    """
    def ll_docs_f(docs):
        dixs, vixs = docs.nonzero()
        vfreqs = docs[dixs, vixs]
        # n = len(dixs) does not work for tensor 
        #  loop the inner logsumexp over each topic  (inner logsumexp: within each topic do the logsumexp)
        #  and the results are stored into reuslts1
        results1, updates1 = theano.scan(lambda phi,psi,vixs: 
                             # N_shareis == length of index == vixs.shape[0]; 
                             pmmath.logsumexp(tt.log(tt.tile(phi, (vixs.shape[0],1))) + tt.log(psi.T[vixs]), axis=1).ravel(), 
                             sequences=phi, 
                             non_sequences=[psi,vixs])
        
        # results1 is a Z x len(dixs) tensor
        ll_docs = vfreqs * pmmath.logsumexp(
            tt.log(theta[dixs])+results1.T, axis=1).ravel()
        return tt.sum(ll_docs)
    return ll_docs_f

# %%
with pm.Model() as lda_model:
    theta = Dirichlet("theta", 
                      a=pm.floatX(1.0/n_topics)*np.ones((sim_counts.shape[0],n_topics)),
                      shape = (sim_counts.shape[0],n_topics), transform=t_stick_breaking(1e-9) )
    phi = Dirichlet("phi", 
                   a=pm.floatX(1.0/n_topics)*np.ones((n_topics,n_subppl)),
                   shape = (n_topics, n_subppl), transform=t_stick_breaking(1e-9))
    psi = Dirichlet("psi", 
                   a=pm.floatX(1.0/n_topics)*np.ones((n_subppl,sim_counts.shape[1])),
                   shape = (n_subppl,sim_counts.shape[1]),transform=t_stick_breaking(1e-9) )
    doc = pm.DensityDist('doc', logp_lda_doc(theta, phi, psi), observed=sim_counts)

# %%
###### Auto-Encoding Variational Bayes
## Encoder
class LDAEncoder:
    def __init__(self, n_genes, n_hidden1, n_hidden2, n_topics, n_subppl, p_corruption=0, random_seed=1):
        rng = np.random.RandomState(random_seed)
        self.n_genes = n_genes
        self.n_hidden1 = n_hidden1
        self.n_hidden2 = n_hidden2
        self.n_topics = n_topics
        self.n_subppl = n_subppl
        self.w0 = shared(0.01 * rng.randn(n_genes, n_hidden1).ravel(), name='w0')
        self.b0 = shared(0.01 * rng.randn(n_hidden1), name='b0')
        self.w1 = shared(0.01 * rng.randn(n_hidden1, n_subppl ).ravel(), name='w1')
        self.b1 = shared(0.01 * rng.randn(n_subppl ), name='b1')
        self.w2 = shared(0.01 * rng.randn(n_subppl , n_hidden2).ravel(), name='w2')
        self.b2 = shared(0.01 * rng.randn(n_hidden2), name='b2')
        self.w3 = shared(0.01 * rng.randn(n_hidden2, 2 * (n_topics - 1)).ravel(), name='w3')
        self.b3 = shared(0.01 * rng.randn(2 * (n_topics - 1)), name='b3')
        self.rng = MRG_RandomStreams(seed=random_seed)
        self.p_corruption = p_corruption
    def encode(self, xs):
        if 0 < self.p_corruption:
            dixs, vixs = xs.nonzero()
            mask = tt.set_subtensor(
                tt.zeros_like(xs)[dixs, vixs],
                self.rng.binomial(size=dixs.shape, n=1, p=1-self.p_corruption)
            )
            xs_ = xs * mask
        else:
            xs_ = xs
        w0 = self.w0.reshape((self.n_genes, self.n_hidden1))
        w1 = self.w1.reshape((self.n_hidden1, self.n_subppl ))
        w2 = self.w2.reshape((self.n_subppl  , self.n_hidden2))   
        w3 = self.w3.reshape((self.n_hidden2, 2 * (n_topics - 1) )) 
        
        h1s = tt.tanh(xs_.dot(w0) + self.b0)
        ks = h1s.dot(w1) +self.b1
        h2s = tt.tanh(ks.dot(w2) + self.b2)
        zs = h2s.dot(w3) + self.b3

        zs_mean = zs[:, :(self.n_topics - 1)]
        zs_std = zs[:, (self.n_topics - 1):]
        return zs_mean, zs_std #, ks_mean, ks_std
    def get_params(self):
        return [self.w0, self.b0, self.w1, self.b1, self.w2, self.b2 , self.w3, self.b3]

# %%
        
encoder = LDAEncoder(n_genes = n_genes, n_hidden1=800, n_hidden2=400, n_topics=n_topics, n_subppl=n_subppl, p_corruption=0.0)
#vi_encoder = encoder.encode(counts_share)
#local_RVs = OrderedDict([(theta, vi_encoder[:2]), (phi, vi_encoder[2:])])
local_RVs = OrderedDict([(theta, encoder.encode(counts_share))])

encoder_params = encoder.get_params()

# %%
with lda_model:
    approx1 = pm.fit(6000, method='advi',
                 local_rv=local_RVs,
                 more_obj_params=encoder_params,
                 # https://arxiv.org/pdf/1705.08292.pdf
                 # sgd(with/without momentum) seems to be good choice for high dimensional problems
                 obj_optimizer=pm.sgd,
                 total_grad_norm_constraint=1000)
    samples = pm.sample_approx(approx1, draws=100)
    theta_pymc3 = samples['theta'].mean(axis=0)
    phi_pymc3 = samples['phi'].mean(axis=0)
    psi_pymc3 = samples['psi'].mean(axis=0)
# Out:
# Average Loss = 7.4987e+06: 100%|██████████| 6000/6000 [1:55:36<00:00,  1.44s/it]
# Finished [100%]: Average Loss = 7.499e+06

# %%
import matplotlib.pyplot as plt
plt.plot(approx1.hist[10:]) 
plt.show()
# encoder = LDAEncoder(n_genes = n_genes, n_hidden=33, n_topics=n_topics, n_subppl=33, p_corruption=0.0)
# 444 x 999 cell by genes
# K5 L6

# %%
theta_pymc3[:100]
# Out:
# array([[  5.63423527e-02,   1.64262921e-05,   1.83723962e-07,
#           1.71561254e-02,   1.88580906e-04,   9.26296331e-01],
#        [  9.99995704e-01,   1.00911850e-06,   9.82223762e-09,
#           1.17305419e-06,   1.19884047e-06,   9.05558728e-07],
#        [  3.65441042e-07,   2.19640220e-01,   7.80343659e-01,
#           6.76163306e-06,   4.90574935e-06,   4.08752907e-06],
#        [  5.82248348e-02,   8.56797841e-06,   1.82798996e-07,
#           8.76730103e-03,   9.08786257e-05,   9.32908235e-01],
#        [  6.79043245e-02,   2.08841844e-05,   1.81214014e-07,
#           2.48792337e-02,   9.55727988e-05,   9.07099804e-01],
#        [  2.39966393e-07,   3.28483208e-01,   6.71501027e-01,
#           6.90647116e-06,   5.93449020e-06,   2.68361191e-06],
#        [  9.99995728e-01,   1.11176248e-06,   1.45744128e-08,
#           1.17228999e-06,   9.55283581e-07,   1.01849244e-06],
#        [  3.09391491e-07,   3.32965502e-01,   6.67024981e-01,
#           4.52540644e-06,   2.88996828e-06,   1.79206268e-06],
#        [  2.95170158e-02,   2.91650213e-05,   1.88142191e-07,
#           2.02497053e-02,   1.68616256e-04,   9.50035310e-01],
#        [  3.23806979e-07,   2.61114073e-01,   7.38865324e-01,
#           1.30038194e-05,   4.78551522e-06,   2.48965955e-06],
#        [  9.99995350e-01,   1.18810074e-06,   1.49364548e-08,
#           1.21602238e-06,   1.03661205e-06,   1.19466776e-06],
#        [  9.99995659e-01,   1.18884666e-06,   1.10187689e-08,
#           8.88227321e-07,   1.34840484e-06,   9.04589134e-07],
#        [  3.13275998e-07,   2.68647752e-01,   7.31337817e-01,
#           7.02898654e-06,   3.97113707e-06,   3.11768669e-06],
#        [  5.13286024e-02,   2.23560923e-04,   1.84291411e-07,
#           1.89751893e-02,   4.04276225e-04,   9.29068187e-01],
#        [  3.45109797e-07,   2.99839069e-01,   7.00129974e-01,
#           2.32390660e-05,   5.21365081e-06,   2.15911202e-06],
#        [  3.29152049e-07,   2.99478449e-01,   7.00499849e-01,
#           4.43367278e-06,   1.18481874e-05,   5.09085128e-06],
#        [  3.33322360e-07,   3.27392019e-01,   6.72598808e-01,
#           4.21383439e-06,   3.06833139e-06,   1.55781063e-06],
#        [  2.76003345e-07,   2.83169331e-01,   7.16815943e-01,
#           9.14722073e-06,   2.83310298e-06,   2.46973021e-06],
#        [  9.99995777e-01,   9.41969613e-07,   9.94693786e-09,
#           9.70473901e-07,   9.68395212e-07,   1.33210851e-06],
#        [  7.36805229e-02,   1.30026863e-05,   1.80892879e-07,
#           3.35158486e-03,   6.50389253e-05,   9.22889670e-01],
#        [  3.05101565e-07,   2.49394847e-01,   7.50592463e-01,
#           3.86353559e-06,   4.03157744e-06,   4.48978682e-06],
#        [  3.27624121e-07,   3.19979055e-01,   6.80007553e-01,
#           6.90655051e-06,   4.70284157e-06,   1.45567968e-06],
#        [  3.12546522e-07,   2.88765456e-01,   7.11223949e-01,
#           3.57245585e-06,   3.57819323e-06,   3.13159493e-06],
#        [  5.73480590e-03,   6.11792696e-03,   1.00055932e-07,
#           9.79359327e-01,   1.96134888e-03,   6.82649141e-03],
#        [  3.29193981e-07,   2.68147641e-01,   7.31836605e-01,
#           8.80495883e-06,   4.02972750e-06,   2.58939164e-06],
#        [  4.59064682e-02,   4.09585605e-05,   1.85974082e-07,
#           5.75408241e-03,   7.95112371e-05,   9.48218794e-01],
#        [  3.41587280e-07,   3.46820877e-01,   6.53165539e-01,
#           6.50074020e-06,   3.46370992e-06,   3.27726708e-06],
#        [  9.14868016e-03,   6.99048721e-03,   9.97469729e-08,
#           9.51714060e-01,   1.61611613e-02,   1.59855113e-02],
#        [  9.99995637e-01,   9.96911300e-07,   1.22288246e-08,
#           1.31381446e-06,   1.10367066e-06,   9.36040890e-07],
#        [  3.13782418e-07,   3.46618164e-01,   6.53347735e-01,
#           2.55819449e-05,   6.11209114e-06,   2.09306785e-06],
#        [  1.42402751e-02,   2.19935105e-05,   1.92030791e-07,
#           1.40718466e-02,   1.07153827e-04,   9.71558539e-01],
#        [  9.99995623e-01,   1.08955871e-06,   2.09732801e-08,
#           1.34484511e-06,   1.17488054e-06,   7.46335955e-07],
#        [  3.04724423e-07,   2.58305913e-01,   7.41670461e-01,
#           6.25625137e-06,   4.88727349e-06,   1.21779225e-05],
#        [  8.31875451e-02,   7.34418200e-05,   1.78234117e-07,
#           2.07602288e-02,   7.73893213e-05,   8.95901217e-01],
#        [  2.51922648e-02,   9.87357482e-04,   9.89011435e-08,
#           9.64139475e-01,   2.63532507e-03,   7.04547846e-03],
#        [  2.77959150e-07,   3.63411443e-01,   6.36579190e-01,
#           4.54448500e-06,   3.09898955e-06,   1.44533591e-06],
#        [  1.37453463e-05,   5.04018427e-04,   3.84179203e-02,
#           7.63009755e-04,   9.60301247e-01,   5.92906872e-08],
#        [  6.84319525e-02,   1.57980272e-05,   1.81140345e-07,
#           4.27793664e-03,   5.20474097e-05,   9.27222084e-01],
#        [  9.99995682e-01,   9.71194326e-07,   3.22387781e-08,
#           1.04458849e-06,   1.03020994e-06,   1.23968851e-06],
#        [  8.11292760e-02,   9.80279844e-06,   1.78382770e-07,
#           1.35369580e-02,   9.53468980e-05,   9.05228438e-01],
#        [  9.09870861e-02,   1.96930865e-05,   1.76946609e-07,
#           1.01874319e-02,   1.37074766e-04,   8.98668537e-01],
#        [  3.02083114e-07,   3.01437392e-01,   6.98550556e-01,
#           6.37847238e-06,   3.96205791e-06,   1.40931657e-06],
#        [  3.33984572e-07,   3.13030468e-01,   6.86959434e-01,
#           4.20328593e-06,   3.39386385e-06,   2.16646679e-06],
#        [  9.99995600e-01,   9.10597700e-07,   1.01880363e-08,
#           1.19274500e-06,   1.04785089e-06,   1.23812674e-06],
#        [  2.95499357e-02,   9.14711356e-06,   1.88543775e-07,
#           1.00188044e-02,   9.76374991e-05,   9.60324287e-01],
#        [  2.87608083e-07,   3.11098363e-01,   6.88877859e-01,
#           5.91469477e-06,   9.12654061e-06,   8.44858770e-06],
#        [  3.19903054e-05,   1.29604291e-04,   5.16618057e-02,
#           5.31415909e-04,   9.47645125e-01,   5.90132754e-08],
#        [  5.91161020e-02,   8.36546185e-06,   1.83037850e-07,
#           1.22576810e-02,   8.92539727e-05,   9.28528415e-01],
#        [  7.85262546e-02,   3.71654610e-04,   1.79319036e-07,
#           1.61664091e-02,   1.12022015e-04,   9.04823480e-01],
#        [  9.99995716e-01,   9.82650190e-07,   1.35166244e-08,
#           1.17005639e-06,   1.26440592e-06,   8.52956145e-07],
#        [  9.99995842e-01,   6.94322934e-07,   1.45193352e-08,
#           1.21246677e-06,   1.06966240e-06,   1.16716610e-06],
#        [  5.68063989e-02,   1.43939814e-04,   1.84055316e-07,
#           5.48325145e-03,   1.52370359e-04,   9.37413855e-01],
#        [  9.99995783e-01,   1.01141013e-06,   4.21842127e-08,
#           8.54432476e-07,   1.20519312e-06,   1.10347685e-06],
#        [  9.99995808e-01,   8.72546783e-07,   1.38314993e-08,
#           1.06891868e-06,   1.10426183e-06,   1.13282728e-06],
#        [  9.99995643e-01,   7.48083378e-07,   1.92252589e-08,
#           1.37951290e-06,   1.27076858e-06,   9.38924851e-07],
#        [  3.59556793e-02,   1.26755997e-05,   1.89702331e-07,
#           2.17703924e-02,   9.65627860e-05,   9.42164500e-01],
#        [  3.22060425e-07,   2.44669324e-01,   7.55311166e-01,
#           7.68468866e-06,   8.64229097e-06,   2.86161994e-06],
#        [  2.78474020e-07,   3.11541505e-01,   6.88440203e-01,
#           6.67566444e-06,   8.81733224e-06,   2.52067580e-06],
#        [  9.41950863e-03,   8.63506770e-05,   1.00434246e-07,
#           9.65734190e-01,   6.19256678e-03,   1.85672834e-02],
#        [  5.08214944e-05,   1.48422249e-04,   3.41009400e-02,
#           1.56547255e-03,   9.64134283e-01,   6.12172285e-08],
#        [  8.95773698e-06,   6.63429579e-05,   1.02307676e-02,
#           3.17079368e-04,   9.89376791e-01,   6.11527213e-08],
#        [  1.38240991e-05,   4.82837416e-05,   6.93003310e-03,
#           8.21529249e-03,   9.84792505e-01,   6.18384890e-08],
#        [  2.84784576e-05,   2.65510562e-04,   1.51148313e-02,
#           6.09840539e-04,   9.83981277e-01,   6.17034344e-08],
#        [  4.51532757e-05,   8.64564402e-05,   2.78044152e-02,
#           7.19766489e-05,   9.71991939e-01,   5.98992112e-08],
#        [  5.29223522e-05,   3.09356842e-05,   2.22622083e-02,
#           1.89792723e-03,   9.75755945e-01,   6.10737798e-08],
#        [  4.45455801e-02,   1.40964345e-05,   1.85306241e-07,
#           1.60563424e-02,   8.76189129e-05,   9.39296177e-01],
#        [  2.87065756e-02,   9.69159488e-04,   9.81491415e-08,
#           9.39368887e-01,   1.52365621e-02,   1.57187174e-02],
#        [  3.37669242e-05,   1.64212839e-04,   3.42498690e-02,
#           2.99892990e-04,   9.65252199e-01,   5.92176233e-08],
#        [  1.93468032e-02,   3.14369839e-03,   9.89840270e-08,
#           9.53092957e-01,   2.14497444e-02,   2.96669752e-03],
#        [  2.34522628e-05,   2.38177227e-04,   2.65337814e-02,
#           4.97151920e-04,   9.72707376e-01,   6.11985740e-08],
#        [  1.54487474e-05,   3.85275195e-05,   1.30742369e-02,
#           6.07536551e-03,   9.80796361e-01,   6.06674023e-08],
#        [  5.07254642e-05,   6.26092904e-05,   1.14486437e-02,
#           3.74486872e-04,   9.88063472e-01,   6.22156537e-08],
#        [  9.99995633e-01,   1.32072910e-06,   1.98166007e-08,
#           1.07817338e-06,   9.48352837e-07,   1.00034298e-06],
#        [  4.56021613e-05,   3.29113352e-04,   2.23673002e-02,
#           4.79244388e-03,   9.72465480e-01,   6.01666341e-08],
#        [  2.00845822e-05,   3.60838545e-04,   2.95945649e-02,
#           7.06526410e-04,   9.69317925e-01,   6.06019368e-08],
#        [  3.10042975e-07,   2.14454979e-01,   7.85529132e-01,
#           6.38045151e-06,   5.78932166e-06,   3.40868414e-06],
#        [  2.50778069e-05,   4.38524915e-05,   3.56644354e-02,
#           5.10595589e-04,   9.63755979e-01,   6.01640646e-08],
#        [  3.70844699e-07,   2.96161826e-01,   7.03820787e-01,
#           7.03011806e-06,   8.44700928e-06,   1.53905991e-06],
#        [  2.83332740e-07,   2.18966793e-01,   7.81012930e-01,
#           6.70925900e-06,   8.47195626e-06,   4.81268940e-06],
#        [  1.42328140e-02,   2.25161492e-03,   9.96486644e-08,
#           9.68966127e-01,   6.33785330e-03,   8.21149108e-03],
#        [  5.11554691e-05,   1.43597114e-04,   2.46862880e-02,
#           9.87490101e-05,   9.75020151e-01,   5.98277571e-08],
#        [  2.09737902e-05,   1.21386440e-05,   3.74647536e-02,
#           6.43348808e-04,   9.61858725e-01,   6.05204319e-08],
#        [  6.66106749e-05,   1.51631637e-04,   3.65528406e-02,
#           9.81007438e-05,   9.63130755e-01,   6.17645940e-08],
#        [  5.26135702e-05,   1.41954609e-04,   2.00008948e-02,
#           4.51213338e-04,   9.79353263e-01,   6.10793769e-08],
#        [  4.58666138e-05,   9.13222583e-05,   4.18647327e-02,
#           2.58309057e-03,   9.55414931e-01,   5.69229750e-08],
#        [  3.52376334e-05,   8.16956609e-05,   3.75159097e-02,
#           3.68810758e-03,   9.58678989e-01,   6.04862777e-08],
#        [  8.90480019e-05,   4.75884052e-05,   2.93308486e-02,
#           6.36517007e-04,   9.69895937e-01,   6.13026945e-08],
#        [  3.14596491e-05,   3.64471182e-05,   1.75800070e-02,
#           2.77889747e-03,   9.79573126e-01,   6.27531022e-08],
#        [  2.01712365e-05,   3.88625820e-04,   3.34918922e-02,
#           1.51315536e-04,   9.65947935e-01,   6.04493965e-08],
#        [  5.46114480e-05,   7.71861905e-05,   2.06132357e-02,
#           4.58531378e-04,   9.78796374e-01,   6.16306824e-08],
#        [  3.35085784e-05,   7.80716830e-05,   1.70541521e-02,
#           1.00016115e-04,   9.82734190e-01,   6.15107384e-08],
#        [  3.27505126e-07,   3.03455116e-01,   6.96526248e-01,
#           1.01073370e-05,   5.63170207e-06,   2.56916900e-06],
#        [  2.39741979e-05,   1.81897470e-04,   1.85715139e-02,
#           3.60996663e-04,   9.80861557e-01,   6.07554703e-08],
#        [  3.28765174e-05,   2.35142929e-05,   1.74051622e-02,
#           2.14895230e-03,   9.80389434e-01,   6.08575847e-08],
#        [  3.12119051e-05,   7.74175937e-05,   2.80144601e-02,
#           4.97396715e-04,   9.71379453e-01,   6.09733037e-08],
#        [  2.91953254e-05,   2.06170061e-05,   2.05113009e-02,
#           9.11727373e-05,   9.79347653e-01,   6.08204153e-08],
#        [  2.10521853e-04,   2.17858387e-04,   3.36277712e-02,
#           2.49181798e-04,   9.65694606e-01,   6.05506182e-08],
#        [  4.05716296e-02,   1.09313636e-02,   9.59839906e-08,
#           9.25900512e-01,   1.52822280e-02,   7.31417075e-03],
#        [  9.99995803e-01,   9.60881504e-07,   2.05408385e-08,
#           1.06503759e-06,   1.02906328e-06,   1.12160036e-06],
#        [  1.26979909e-04,   9.28570222e-04,   3.79611174e-02,
#           1.74167138e-04,   9.60809105e-01,   5.99733389e-08]])

# %%
## get label for each cell
celda_z = np.load("./celda_simulated/simCG_z_K5L6.npy")  # cell clusters 
pymc3_z = theta_pymc3.argmax(axis=1)
pd.DataFrame({"celda_z":celda_z, "pymc3_z":pymc3_z}).groupby(["pymc3_z","celda_z"]).size() 
# simulated result from celda_CG(seed=77)
# Out:
# pymc3_z  celda_z
# 0        1          136
# 1        3          102
# 2        5           41
# 3        4           51
# 4        2          114
# dtype: int64

# %%
celda_y = np.load("./celda_simulated/simCG_y_K5L6.npy")
pymc3_y = psi_pymc3.argmax(axis=0)
pd.DataFrame({"celda_y":celda_y, "pymc3_y":pymc3_y}).groupby(["pymc3_y","celda_y"]).size()
# Out:
# pymc3_y  celda_y
# 0        1           13
#          3          157
# 1        1           85
#          2           90
#          5           87
# 2        1           60
#          2           20
#          3           19
#          4            5
# 3        4          137
# 4        2            1
#          6            2
# 5        1           84
#          2           89
#          3           31
#          4           89
#          5           30
# dtype: int64

# %%
df1 =pd.DataFrame({"celda_y":celda_y, "pymc3_y":pymc3_y}).groupby(["pymc3_y","celda_y"]).size().reset_index() 
df1.columns = ["pymc3_y","celda_y","count"]
print(df1.pivot(index="pymc3_y", columns="celda_y",values="count"))
print( (157+87+60+137+2+89)/ sim_counts.shape[1] )
# Out:
# celda_y     1     2      3      4     5    6
# pymc3_y
# 0        13.0   NaN  157.0    NaN   NaN  NaN
# 1        85.0  90.0    NaN    NaN  87.0  NaN
# 2        60.0  20.0   19.0    5.0   NaN  NaN
# 3         NaN   NaN    NaN  137.0   NaN  NaN
# 4         NaN   1.0    NaN    NaN   NaN  2.0
# 5        84.0  89.0   31.0   89.0  30.0  NaN
# 0.5325325325325325
